# %%
# Import requirements
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
# Load dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
# Normalize dataset
X_train = X_train/255.0
X_test = X_test/255.0

# %%
# Show Label
imgIdx = 8
image = X_train[imgIdx]
print('Image label:', y_train[imgIdx])
plt.imshow(image)
# Out:
# Image label: 5

# %%
# Create NN model
model = Sequential()
model.add(Flatten(input_shape=[28, 28]))
model.add(Dense(300, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense (Dense)               (None, 300)               235500
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266610 (1.02 MB)
# Trainable params: 266610 (1.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile model
model.compile(loss='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
# Fit model
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2, verbose=True)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 11s 8ms/step - loss: 0.3683 - accuracy: 0.8631 - val_loss: 0.3746 - val_accuracy: 0.8643
# Epoch 2/20
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.3276 - accuracy: 0.8774 - val_loss: 0.3534 - val_accuracy: 0.8743
# Epoch 3/20
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.3081 - accuracy: 0.8842 - val_loss: 0.3435 - val_accuracy: 0.8747
# Epoch 4/20
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.2881 - accuracy: 0.8917 - val_loss: 0.3323 - val_accuracy: 0.8800
# Epoch 5/20
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2733 - accuracy: 0.8974 - val_loss: 0.3193 - val_accuracy: 0.8858
# Epoch 6/20
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2627 - accuracy: 0.9017 - val_loss: 0.3244 - val_accuracy: 0.8863
# Epoch 7/20
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.2462 - accuracy: 0.9060 - val_loss: 0.3397 - val_accuracy: 0.8830
# Epoch 8/20
# 1500/1500 [==============================] - 14s 10ms/step - loss: 0.2378 - accuracy: 0.9094 - val_loss: 0.3248 - val_accuracy: 0.8827
# Epoch 9/20
# 1500/1500 [==============================] - 16s 11ms/step - loss: 0.2277 - accuracy: 0.9124 - val_loss: 0.3225 - val_accuracy: 0.8903
# Epoch 10/20
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.2194 - accuracy: 0.9161 - val_loss: 0.3108 - val_accuracy: 0.8936
# Epoch 11/20
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2096 - accuracy: 0.9196 - val_loss: 0.3328 - val_accuracy: 0.8890
# Epoch 12/20
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2033 - accuracy: 0.9233 - val_loss: 0.3416 - val_accuracy: 0.8915
# Epoch 13/20
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1976 - accuracy: 0.9243 - val_loss: 0.3830 - val_accuracy: 0.8747
# Epoch 14/20
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1890 - accuracy: 0.9266 - val_loss: 0.3427 - val_accuracy: 0.8887
# Epoch 15/20
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.1811 - accuracy: 0.9296 - val_loss: 0.3480 - val_accuracy: 0.8909
# Epoch 16/20
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1784 - accuracy: 0.9315 - val_loss: 0.3555 - val_accuracy: 0.8897
# Epoch 17/20
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1706 - accuracy: 0.9341 - val_loss: 0.3523 - val_accuracy: 0.8945
# Epoch 18/20
# 1500/1500 [==============================] - 11s 8ms/step - loss: 0.1646 - accuracy: 0.9363 - val_loss: 0.3814 - val_accuracy: 0.8876
# Epoch 19/20
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1615 - accuracy: 0.9374 - val_loss: 0.3672 - val_accuracy: 0.8895
# Epoch 20/20
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.1531 - accuracy: 0.9412 - val_loss: 0.3724 - val_accuracy: 0.8895

# %%
# Plot training & validation accuracy values
plt.figure(figsize=[6,4])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=[6,4])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Evaluate model
result = model.evaluate(X_test,  y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4251 - accuracy: 0.8856
# Loss:

# %%
# Predict data
x_pred = X_test[:5]
predictions = model.predict(x_pred)
print(np.argmax(predictions, axis=1))
# Out:
# 1/1 [==============================] - 0s 199ms/step
# [9 2 1 1 6]
